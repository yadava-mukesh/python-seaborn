# %% [markdown]
# # Data Analytics Project
# - Understanding of business problem
# - Data Understanding
#    - collect data from source
#    - Data Exploration
#       - Understand every column (do research, ask seniors).
#       - Understand each variable clearly by using discriptive statistics.
#       - Observe the complete given data by Pandas and Seaborn.
# - Data Preprocessing or Data Preparation
#    - Data Cleaning
#       - wrong data
#       - wrong data type
#       - missing values
#       - duplicates
#       - outliers
# ***Once data cleaned, keep data as cleaned data***
# - Analysis
# - Presentation

# %% [markdown]
# # Step-1 : Business Problem
# - Restaurent owner wants detailed report on sales.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('C:\\Users\\yadav\\Downloads\\Jupyter\\Datasets\\tips_data.xlsx')
df
# Out:
#     total_bill   tip     sex smoker   day    time  size
# 0        21.85  9.73    Male     No  Thur  Dinner     4
# 1        47.78  7.98  Female    Yes  Thur   Lunch     3
# 2        37.94  9.46    Male     No   Sat   Lunch     1
# 3        31.94  9.05    Male    Yes   Fri  Dinner     4
# 4        12.02  6.38  Female    Yes   Fri  Dinner     6
# 5        12.02  9.30    Male    Yes  Thur   Lunch     4
# 6         7.61  1.80  Female    Yes   Sun  Dinner     6
# 7        43.98  2.76  Female     No   Fri  Dinner     3
# 8        32.05  1.41  Female     No   Sun   Lunch     6
# 9        36.86  3.93    Male    Yes   Fri   Lunch     1
# 10        5.93  4.50    Male    Yes   Sun  Dinner     3
# 11       48.65  3.44    Male     No   Sat   Lunch     1
# 12       42.46  8.46    Male    Yes   Sun   Lunch     5
# 13       14.56  4.21    Male    Yes   Sat  Dinner     2
# 14       13.18  3.53    Male    Yes   Sat   Lunch     6
# 15       13.25  5.88    Male     No   Sun   Lunch     2
# ...

# %%
df.describe()
# Out:
#        total_bill       tip     size
# count   50.000000  50.00000  50.0000
# mean    25.066800   5.45040   3.7600
# std     12.999071   2.76149   1.8357
# min      5.930000   1.05000   1.0000
# 25%     13.267500   2.95250   2.2500
# 50%     24.625000   5.57000   4.0000
# 75%     34.240000   7.94000   6.0000
# max     48.650000   9.88000   6.0000

# %% [markdown]
# ***Wrong datatype, wrong data, duplicate, missing data, outliers***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  50 non-null     float64
#  1   tip         50 non-null     float64
#  2   sex         50 non-null     object
#  3   smoker      50 non-null     object
#  4   day         50 non-null     object
#  5   time        50 non-null     object
#  6   size        50 non-null     int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 2.9+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#     total_bill   tip     sex smoker   day    time  size
# 0        21.85  9.73    Male     No  Thur  Dinner     4
# 1        47.78  7.98  Female    Yes  Thur   Lunch     3
# 2        37.94  9.46    Male     No   Sat   Lunch     1
# 3        31.94  9.05    Male    Yes   Fri  Dinner     4
# 4        12.02  6.38  Female    Yes   Fri  Dinner     6
# 5        12.02  9.30    Male    Yes  Thur   Lunch     4
# 6         7.61  1.80  Female    Yes   Sun  Dinner     6
# 7        43.98  2.76  Female     No   Fri  Dinner     3
# 8        32.05  1.41  Female     No   Sun   Lunch     6
# 9        36.86  3.93    Male    Yes   Fri   Lunch     1
# 10        5.93  4.50    Male    Yes   Sun  Dinner     3
# 11       48.65  3.44    Male     No   Sat   Lunch     1
# 12       42.46  8.46    Male    Yes   Sun   Lunch     5
# 13       14.56  4.21    Male    Yes   Sat  Dinner     2
# 14       13.18  3.53    Male    Yes   Sat   Lunch     6
# 15       13.25  5.88    Male     No   Sun   Lunch     2
# ...

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.groupby('sex')['total_bill'].describe().transpose()
# Out:
# sex       Female       Male
# count  24.000000  26.000000
# mean   25.643333  24.534615
# std    13.980214  12.278775
# min     6.550000   5.930000
# 25%    12.507500  13.487500
# 50%    24.625000  24.565000
# 75%    36.190000  32.382500
# max    48.450000  48.650000

# %%
df.groupby('smoker')['total_bill'].describe().transpose()
# Out:
# smoker         No        Yes
# count   25.000000  25.000000
# mean    26.398400  23.735200
# std     12.879844  13.244164
# min      7.090000   5.930000
# 25%     16.650000  12.020000
# 50%     24.810000  24.440000
# 75%     34.810000  31.940000
# max     48.650000  47.780000

# %%
df.groupby('day')['total_bill'].describe().transpose()
# Out:
# day          Fri        Sat        Sun       Thur
# count  10.000000  16.000000  16.000000   8.000000
# mean   32.462000  22.346250  24.120000  23.157500
# std    12.663815  13.370659  12.460921  12.631661
# min    12.020000   6.550000   5.930000  11.280000
# 25%    22.497500  13.285000  11.920000  12.507500
# 50%    34.400000  17.670000  27.840000  20.280000
# 75%    43.067500  29.807500  32.170000  29.542500
# max    48.450000  48.650000  42.460000  47.780000

# %% [markdown]
# # Histogram and Distribution plot

# %%
df['total_bill'].skew()
# Out:
# 0.3012467608226219

# %%
sns.histplot(df['total_bill'],bins=10, kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.kdeplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ***Box plot***

# %%
sns.boxplot(y=df['tip'])
plt.show()

# %%
sns.boxplot(y=df['total_bill'])
plt.show()

# %% [markdown]
# ***Scatter plot***

# %%
sns.scatterplot(x=df['total_bill'], y=df['tip'], hue=df['sex'])
plt.show()

# %%
df['size'].unique()
# Out:
# array([4, 3, 1, 6, 5, 2], dtype=int64)

# %%
sns.relplot(x=df['total_bill'], y=df['tip'], col=df['size'], col_wrap=2, hue=df['sex'])

# %% [markdown]
# # Bar plot

# %%
df.groupby('sex')['total_bill'].mean()
# Out:
# sex
# Female    25.643333
# Male      24.534615
# Name: total_bill, dtype: float64

# %%
sns.catplot(x='sex',y='total_bill', data=df, kind='bar')
plt.show()

# %%
sns.catplot(x='sex',y='total_bill', data=df,hue=df['size'], kind='bar')
plt.show()

# %%
sns.catplot(x='day',y='total_bill', data=df, kind='box')
plt.show()

# %% [markdown]
# ***Cross tab***

# %%
pd.crosstab(df['sex'], df['time'])
# Out:
# time    Dinner  Lunch
# sex
# Female      13     11
# Male        13     13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  50 non-null     float64
#  1   tip         50 non-null     float64
#  2   sex         50 non-null     object
#  3   smoker      50 non-null     object
#  4   day         50 non-null     object
#  5   time        50 non-null     object
#  6   size        50 non-null     int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 2.9+ KB

# %%
pd.crosstab(df['smoker'], df['day'])
# Out:
# day     Fri  Sat  Sun  Thur
# smoker
# No        5    8    7     5
# Yes       5    8    9     3

# %%
pd.crosstab(df['smoker'], df['time'])
# Out:
# time    Dinner  Lunch
# smoker
# No          15     10
# Yes         11     14

# %%
pd.crosstab(df['day'], df['time'], margins=True)         #here margins will give sum
# Out:
# time  Dinner  Lunch  All
# day
# Fri        6      4   10
# Sat        6     10   16
# Sun        9      7   16
# Thur       5      3    8
# All       26     24   50
